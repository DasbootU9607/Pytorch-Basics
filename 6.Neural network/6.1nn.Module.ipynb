# %%
# Example
def forward(self,x):
    x=F.relu(self.conv1(x))   # 非线性（卷级（x））
    return F.relu(self.conv2(x))    # 非线性（卷级（非线性（卷级（x））））

# %% [markdown]
# ### Build a Neural Network

# %%
import torch
from torch import nn

# %%
class Example(nn.Module):
    def __init__(self):
        super().__init__()
    
    def forward(self,input):
        output=input+1
        return output

# %%
eg=Example()
x=torch.tensor(1.0)
output=eg(x)
print(output)
